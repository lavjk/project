# %%
import pandas as pd
df=pd.read_csv('C:\\Users\\GPT-INF003\\Downloads\\productivity_n_hourly_compensation.csv')
df
# Out:
#     year  net_productivity_per_hour_worked  \
# 0   2021                             91.08
# 1   2020                             89.54
# 2   2019                             88.10
# 3   2018                             87.00
# 4   2017                             86.10
# 5   2016                             85.54
# 6   2015                             85.46
# 7   2014                             84.23
# 8   2013                             83.90
# 9   2012                             83.22
# 10  2011                             83.00
# 11  2010                             83.81
# 12  2009                             81.42
# 13  2008                             78.60
# 14  2007                             79.41
# 15  2006                             78.73
# 16  2005                             78.38
# 17  2004                             77.24
# 18  2003                             75.15
# 19  2002                             72.79
# 20  2001                             70.75
# 21  2000                             69.94
# 22  1999                             69.13
# 23  1998                             67.65
# 24  1997                             66.28
# 25  1996                             65.27
# 26  1995                             64.46
# 27  1994                             64.40
# 28  1993                             63.81
# 29  1992                             63.54
# 30  1991                             61.15
# 31  1990                             60.77
# 32  1989                             60.56
# 33  1988                             60.14
# 34  1987                             59.30
# 35  1986                             59.65
# 36  1985                             58.28
# 37  1984                             57.36
# 38  1983                             56.02
# 39  1982                             54.36
# 40  1981                             54.83
# 41  1980                             53.87
# 42  1979                             55.34
# 43  1978                             56.04
# 44  1977                             55.41
# 45  1976                             54.93
# 46  1975                             53.58
# 47  1974                             52.13
# 48  1973                             53.60
#
#     average_compensation_of_production_and_nonsupervisory_workers  \
# 0                                               31.55
# 1                                               31.62
# 2                                               30.57
# 3                                               30.14
# 4                                               29.95
# 5                                               29.91
# 6                                               29.66
# 7                                               29.19
# 8                                               29.12
# 9                                               28.84
# 10                                              29.12
# 11                                              29.47
# 12                                              29.23
# 13                                              28.15
# 14                                              28.14
# 15                                              27.91
# 16                                              27.91
# 17                                              28.02
# 18                                              28.14
# 19                                              27.86
# 20                                              27.32
# 21                                              26.93
# 22                                              26.80
# 23                                              26.44
# 24                                              25.82
# 25                                              25.54
# 26                                              25.53
# 27                                              25.68
# 28                                              25.61
# 29                                              25.57
# 30                                              25.40
# 31                                              25.44
# 32                                              25.66
# 33                                              25.66
# 34                                              25.74
# 35                                              26.10
# 36                                              25.94
# 37                                              26.06
# 38                                              26.25
# 39                                              26.14
# 40                                              26.08
# 41                                              26.17
# 42                                              26.89
# 43                                              27.21
# 44                                              26.81
# 45                                              26.32
# 46                                              25.96
# 47                                              25.99
# 48                                              26.53
#
#     average_compensation  median_compensation  men_median_compensation  \
# 0                  49.39                26.01                    24.22
# 1                  49.59                26.80                    24.62
# 2                  47.05                25.13                    23.20
# 3                  46.40                24.95                    22.48
# 4                  46.03                24.52                    22.41
# 5                  45.58                24.34                    22.15
# 6                  45.59                23.97                    21.78
# 7                  44.41                23.66                    21.34
# 8                  44.00                23.72                    21.69
# 9                  43.96                23.51                    21.76
# 10                 43.93                23.90                    22.22
# 11                 44.42                24.54                    22.41
# 12                 44.33                24.67                    22.50
# 13                 43.51                24.02                    21.88
# 14                 43.69                24.17                    21.65
# 15                 43.02                24.20                    21.64
# 16                 42.76                24.24                    21.62
# 17                 42.65                24.57                    21.71
# 18                 41.94                24.25                    21.97
# 19                 41.23                24.09                    21.63
# 20                 40.87                23.57                    20.86
# 21                 40.22                23.10                    20.33
# 22                 39.06                22.96                    20.03
# 23                 38.22                22.42                    20.14
# 24                 36.95                21.69                    19.38
# 25                 36.51                21.39                    19.13
# 26                 36.10                21.87                    19.25
# 27                 36.27                22.39                    19.46
# 28                 36.29                22.70                    19.66
# 29                 36.42                22.33                    19.31
# 30                 35.37                21.96                    19.21
# 31                 34.81                22.06                    18.85
# 32                 34.66                22.07                    18.87
# 33                 34.97                22.02                    18.92
# 34                 34.39                22.32                    18.53
# 35                 34.25                22.17                    18.37
# 36                 33.17                21.98                    18.02
# 37                 32.51                21.62                    17.88
# 38                 32.34                21.54                    17.59
# 39                 32.23                21.41                    17.21
# 40                 31.62                21.41                    17.33
# 41                 31.53                21.54                    17.17
# 42                 31.71                21.61                    17.18
# 43                 31.82                21.91                    17.00
# 44                 31.45                21.65                    16.89
# 45                 31.06                21.45                    16.88
# 46                 30.48                21.42                    16.67
# 47                 30.03                21.13                    16.22
# 48                 30.21                21.46                    16.39
#
#     women_median_compensation
# 0                       28.13
# 1                       29.41
# 2                       27.31
# 3                       26.68
# 4                       27.06
# 5                       26.71
# 6                       26.48
# 7                       25.69
# 8                       26.02
# 9                       26.18
# 10                      26.16
# 11                      26.86
# 12                      27.47
# 13                      26.60
# 14                      26.59
# 15                      26.54
# 16                      26.35
# 17                      26.91
# 18                      27.35
# 19                      27.09
# 20                      26.53
# 21                      26.22
# 22                      25.91
# 23                      25.36
# 24                      24.76
# 25                      24.50
# 26                      24.80
# 27                      24.89
# 28                      25.28
# 29                      25.20
# 30                      25.01
# 31                      25.13
# 32                      26.10
# 33                      26.91
# 34                      26.84
# 35                      26.86
# 36                      26.54
# 37                      26.39
# 38                      26.23
# 39                      26.63
# 40                      26.50
# 41                      26.95
# 42                      27.13
# 43                      27.21
# 44                      26.75
# 45                      26.28
# 46                      26.60
# 47                      25.84
# 48                      26.06

# %%
df.head()
# Out:
#    year  net_productivity_per_hour_worked  \
# 0  2021                             91.08
# 1  2020                             89.54
# 2  2019                             88.10
# 3  2018                             87.00
# 4  2017                             86.10
#
#    average_compensation_of_production_and_nonsupervisory_workers  \
# 0                                              31.55
# 1                                              31.62
# 2                                              30.57
# 3                                              30.14
# 4                                              29.95
#
#    average_compensation  median_compensation  men_median_compensation  \
# 0                 49.39                26.01                    24.22
# 1                 49.59                26.80                    24.62
# 2                 47.05                25.13                    23.20
# 3                 46.40                24.95                    22.48
# 4                 46.03                24.52                    22.41
#
#    women_median_compensation
# 0                      28.13
# 1                      29.41
# 2                      27.31
# 3                      26.68
# 4                      27.06

# %%
df.shape
# Out:
# (49, 7)

# %%
df.isnull().sum()
# Out:
# year                                                             0
# net_productivity_per_hour_worked                                 0
# average_compensation_of_production_and_nonsupervisory_workers    0
# average_compensation                                             0
# median_compensation                                              0
# men_median_compensation                                          0
# women_median_compensation                                        0
# dtype: int64

# %%
df.isnull().any()
# Out:
# year                                                             False
# net_productivity_per_hour_worked                                 False
# average_compensation_of_production_and_nonsupervisory_workers    False
# average_compensation                                             False
# median_compensation                                              False
# men_median_compensation                                          False
# women_median_compensation                                        False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 7 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   year                                                           49 non-null     int64
#  1   net_productivity_per_hour_worked                               49 non-null     float64
#  2   average_compensation_of_production_and_nonsupervisory_workers  49 non-null     float64
#  3   average_compensation                                           49 non-null     float64
#  4   median_compensation                                            49 non-null     float64
#  5   men_median_compensation                                        49 non-null     float64
#  6   women_median_compensation                                      49 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 2.8 KB

# %%
df.describe()
# Out:
#              year  net_productivity_per_hour_worked  \
# count    49.00000                         49.000000
# mean   1997.00000                         69.290816
# std      14.28869                         12.337202
# min    1973.00000                         52.130000
# 25%    1985.00000                         58.280000
# 50%    1997.00000                         66.280000
# 75%    2009.00000                         81.420000
# max    2021.00000                         91.080000
#
#        average_compensation_of_production_and_nonsupervisory_workers  \
# count                                          49.000000
# mean                                           27.389592
# std                                             1.753758
# min                                            25.400000
# 25%                                            25.960000
# 50%                                            26.810000
# 75%                                            28.840000
# max                                            31.620000
#
#        average_compensation  median_compensation  men_median_compensation  \
# count             49.000000            49.000000                49.000000
# mean              38.551020            22.987959                19.951224
# std                5.797938             1.404987                 2.233136
# min               30.030000            21.130000                16.220000
# 25%               33.170000            21.690000                18.020000
# 50%               36.950000            22.420000                19.660000
# 75%               43.930000            24.170000                21.760000
# max               49.590000            26.800000                24.620000
#
#        women_median_compensation
# count                  49.000000
# mean                   26.387755
# std                     0.901996
# min                    24.500000
# 25%                    26.020000
# 50%                    26.530000
# 75%                    26.860000
# max                    29.410000

# %%
print('lenghth of dataset:',len(df))
# Out:
# lenghth of dataset: 49

# %%
import matplotlib.pyplot as plt
df['average_compensation'].plot(figsize=(16,6))
plt.title('Linechart')
plt.xlabel('Open')
plt.ylabel('frequency')
plt.show()

# %%
x=df.drop('net_productivity_per_hour_worked',axis=1)
x
# Out:
#     year  average_compensation_of_production_and_nonsupervisory_workers  \
# 0   2021                                              31.55
# 1   2020                                              31.62
# 2   2019                                              30.57
# 3   2018                                              30.14
# 4   2017                                              29.95
# 5   2016                                              29.91
# 6   2015                                              29.66
# 7   2014                                              29.19
# 8   2013                                              29.12
# 9   2012                                              28.84
# 10  2011                                              29.12
# 11  2010                                              29.47
# 12  2009                                              29.23
# 13  2008                                              28.15
# 14  2007                                              28.14
# 15  2006                                              27.91
# 16  2005                                              27.91
# 17  2004                                              28.02
# 18  2003                                              28.14
# 19  2002                                              27.86
# 20  2001                                              27.32
# 21  2000                                              26.93
# 22  1999                                              26.80
# 23  1998                                              26.44
# 24  1997                                              25.82
# 25  1996                                              25.54
# 26  1995                                              25.53
# 27  1994                                              25.68
# 28  1993                                              25.61
# 29  1992                                              25.57
# 30  1991                                              25.40
# 31  1990                                              25.44
# 32  1989                                              25.66
# 33  1988                                              25.66
# 34  1987                                              25.74
# 35  1986                                              26.10
# 36  1985                                              25.94
# 37  1984                                              26.06
# 38  1983                                              26.25
# 39  1982                                              26.14
# 40  1981                                              26.08
# 41  1980                                              26.17
# 42  1979                                              26.89
# 43  1978                                              27.21
# 44  1977                                              26.81
# 45  1976                                              26.32
# 46  1975                                              25.96
# 47  1974                                              25.99
# 48  1973                                              26.53
#
#     average_compensation  median_compensation  men_median_compensation  \
# 0                  49.39                26.01                    24.22
# 1                  49.59                26.80                    24.62
# 2                  47.05                25.13                    23.20
# 3                  46.40                24.95                    22.48
# 4                  46.03                24.52                    22.41
# 5                  45.58                24.34                    22.15
# 6                  45.59                23.97                    21.78
# 7                  44.41                23.66                    21.34
# 8                  44.00                23.72                    21.69
# 9                  43.96                23.51                    21.76
# 10                 43.93                23.90                    22.22
# 11                 44.42                24.54                    22.41
# 12                 44.33                24.67                    22.50
# 13                 43.51                24.02                    21.88
# 14                 43.69                24.17                    21.65
# 15                 43.02                24.20                    21.64
# 16                 42.76                24.24                    21.62
# 17                 42.65                24.57                    21.71
# 18                 41.94                24.25                    21.97
# 19                 41.23                24.09                    21.63
# 20                 40.87                23.57                    20.86
# 21                 40.22                23.10                    20.33
# 22                 39.06                22.96                    20.03
# 23                 38.22                22.42                    20.14
# 24                 36.95                21.69                    19.38
# 25                 36.51                21.39                    19.13
# 26                 36.10                21.87                    19.25
# 27                 36.27                22.39                    19.46
# 28                 36.29                22.70                    19.66
# 29                 36.42                22.33                    19.31
# 30                 35.37                21.96                    19.21
# 31                 34.81                22.06                    18.85
# 32                 34.66                22.07                    18.87
# 33                 34.97                22.02                    18.92
# 34                 34.39                22.32                    18.53
# 35                 34.25                22.17                    18.37
# 36                 33.17                21.98                    18.02
# 37                 32.51                21.62                    17.88
# 38                 32.34                21.54                    17.59
# 39                 32.23                21.41                    17.21
# 40                 31.62                21.41                    17.33
# 41                 31.53                21.54                    17.17
# 42                 31.71                21.61                    17.18
# 43                 31.82                21.91                    17.00
# 44                 31.45                21.65                    16.89
# 45                 31.06                21.45                    16.88
# 46                 30.48                21.42                    16.67
# 47                 30.03                21.13                    16.22
# 48                 30.21                21.46                    16.39
#
#     women_median_compensation
# 0                       28.13
# 1                       29.41
# 2                       27.31
# 3                       26.68
# 4                       27.06
# 5                       26.71
# 6                       26.48
# 7                       25.69
# 8                       26.02
# 9                       26.18
# 10                      26.16
# 11                      26.86
# 12                      27.47
# 13                      26.60
# 14                      26.59
# 15                      26.54
# 16                      26.35
# 17                      26.91
# 18                      27.35
# 19                      27.09
# 20                      26.53
# 21                      26.22
# 22                      25.91
# 23                      25.36
# 24                      24.76
# 25                      24.50
# 26                      24.80
# 27                      24.89
# 28                      25.28
# 29                      25.20
# 30                      25.01
# 31                      25.13
# 32                      26.10
# 33                      26.91
# 34                      26.84
# 35                      26.86
# 36                      26.54
# 37                      26.39
# 38                      26.23
# 39                      26.63
# 40                      26.50
# 41                      26.95
# 42                      27.13
# 43                      27.21
# 44                      26.75
# 45                      26.28
# 46                      26.60
# 47                      25.84
# 48                      26.06

# %%
y=df['net_productivity_per_hour_worked']
y
# Out:
# 0     91.08
# 1     89.54
# 2     88.10
# 3     87.00
# 4     86.10
# 5     85.54
# 6     85.46
# 7     84.23
# 8     83.90
# 9     83.22
# 10    83.00
# 11    83.81
# 12    81.42
# 13    78.60
# 14    79.41
# 15    78.73
# 16    78.38
# 17    77.24
# 18    75.15
# 19    72.79
# 20    70.75
# 21    69.94
# 22    69.13
# 23    67.65
# 24    66.28
# 25    65.27
# 26    64.46
# 27    64.40
# 28    63.81
# 29    63.54
# 30    61.15
# 31    60.77
# 32    60.56
# 33    60.14
# 34    59.30
# 35    59.65
# 36    58.28
# 37    57.36
# 38    56.02
# 39    54.36
# 40    54.83
# 41    53.87
# 42    55.34
# 43    56.04
# 44    55.41
# 45    54.93
# 46    53.58
# 47    52.13
# 48    53.60
# Name: net_productivity_per_hour_worked, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (36, 6)
# (13, 6)
# (36,)
# (13,)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.coef_)
# Out:
# [ 0.02158403  1.88917947  1.71830426  0.05009886 -0.19359418 -1.78893131]

# %%
print(regressor.intercept_)
# Out:
# -41.991674858573745

# %%
predicted=regressor.predict(x_test)
predicted
# Out:
# array([64.19000363, 85.69927666, 64.33347386, 62.3837594 , 59.73317976,
#        56.33690092, 58.13174148, 54.67981523, 84.02999192, 82.00907436,
#        82.2337007 , 61.3355242 , 58.78305104])

# %%
print(x_test)
# Out:
#     year  average_compensation_of_production_and_nonsupervisory_workers  \
# 29  1992                                              25.57
# 4   2017                                              29.95
# 26  1995                                              25.53
# 30  1991                                              25.40
# 32  1989                                              25.66
# 37  1984                                              26.06
# 34  1987                                              25.74
# 40  1981                                              26.08
# 7   2014                                              29.19
# 10  2011                                              29.12
# 11  2010                                              29.47
# 31  1990                                              25.44
# 33  1988                                              25.66
#
#     average_compensation  median_compensation  men_median_compensation  \
# 29                 36.42                22.33                    19.31
# 4                  46.03                24.52                    22.41
# 26                 36.10                21.87                    19.25
# 30                 35.37                21.96                    19.21
# 32                 34.66                22.07                    18.87
# 37                 32.51                21.62                    17.88
# 34                 34.39                22.32                    18.53
# 40                 31.62                21.41                    17.33
# 7                  44.41                23.66                    21.34
# 10                 43.93                23.90                    22.22
# 11                 44.42                24.54                    22.41
# 31                 34.81                22.06                    18.85
# 33                 34.97                22.02                    18.92
#
#     women_median_compensation
# 29                      25.20
# 4                       27.06
# 26                      24.80
# 30                      25.01
# 32                      26.10
# 37                      26.39
# 34                      26.84
# 40                      26.50
# 7                       25.69
# 10                      26.16
# 11                      26.86
# 31                      25.13
# 33                      26.91

# %%
predicted.shape
# Out:
# (13,)

# %%
dframe=pd.DataFrame(y_test,predicted)
dframe
# Out:
#            net_productivity_per_hour_worked
# 64.190004                               NaN
# 85.699277                               NaN
# 64.333474                               NaN
# 62.383759                               NaN
# 59.733180                               NaN
# 56.336901                               NaN
# 58.131741                               NaN
# 54.679815                               NaN
# 84.029992                               NaN
# 82.009074                               NaN
# 82.233701                               NaN
# 61.335524                               NaN
# 58.783051                               NaN

# %%
dfr=pd.DataFrame({'Actual Price':y_test,'Predicted Price':predicted})
dfr
# Out:
#     Actual Price  Predicted Price
# 29         63.54        64.190004
# 4          86.10        85.699277
# 26         64.46        64.333474
# 30         61.15        62.383759
# 32         60.56        59.733180
# 37         57.36        56.336901
# 34         59.30        58.131741
# 40         54.83        54.679815
# 7          84.23        84.029992
# 10         83.00        82.009074
# 11         83.81        82.233701
# 31         60.77        61.335524
# 33         60.14        58.783051

# %%
dfr.head(40)
# Out:
#     Actual Price  Predicted Price
# 29         63.54        64.190004
# 4          86.10        85.699277
# 26         64.46        64.333474
# 30         61.15        62.383759
# 32         60.56        59.733180
# 37         57.36        56.336901
# 34         59.30        58.131741
# 40         54.83        54.679815
# 7          84.23        84.029992
# 10         83.00        82.009074
# 11         83.81        82.233701
# 31         60.77        61.335524
# 33         60.14        58.783051

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(x_train,y_train)
print('train_accuracy:',train_accuracy)
test_accuracy=regressor.score(x_test,y_test)
print('test_accuracy:',test_accuracy)
# Out:
# train_accuracy: 0.9949918060732188
# test_accuracy: 0.9934898217061862

# %%
import math
from sklearn import metrics
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,predicted))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,predicted))
print('Root Mean Squared Error:',math.sqrt(metrics.mean_squared_error(y_test,predicted)))
# Out:
# Mean Absolute Error: 0.7899293297402755
# Mean Squared Error: 0.8389835646655838
# Root Mean Squared Error: 0.9159604602086183

# %%
graph=dfr.head(20)
graph
# Out:
#     Actual Price  Predicted Price
# 29         63.54        64.190004
# 4          86.10        85.699277
# 26         64.46        64.333474
# 30         61.15        62.383759
# 32         60.56        59.733180
# 37         57.36        56.336901
# 34         59.30        58.131741
# 40         54.83        54.679815
# 7          84.23        84.029992
# 10         83.00        82.009074
# 11         83.81        82.233701
# 31         60.77        61.335524
# 33         60.14        58.783051

# %%
graph.plot(kind='bar')
plt.title('BarGraph')
plt.xlabel('Actual&prediceted price')
plt.ylabel('frequency')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.90,random_state=100)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4, 6)
# (45, 6)
# (4,)
# (45,)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=100,random_state=0)
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
predicted=regressor.predict(x_test)
predicted
# Out:
# array([82.8488, 73.3112, 64.4242, 68.9592, 62.517 , 62.5378, 83.8572,
#        65.2794, 61.6826, 66.596 , 83.8572, 83.0822, 62.1906, 78.8918,
#        62.9938, 65.7616, 63.1442, 79.1708, 82.81  , 62.3098, 62.517 ,
#        66.596 , 77.7054, 70.9746, 82.2908, 83.8572, 83.8572, 83.0822,
#        68.073 , 62.5378, 70.6482, 66.596 , 83.2244, 78.3794, 62.517 ,
#        62.5378, 62.5378, 80.4516, 61.3562, 83.8572, 63.9474, 66.596 ,
#        83.3794, 80.4516, 68.6584])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
train_accuracy=regressor.score(x_train,y_train)
print('train_accuracy:',train_accuracy)
R_test_accuracy=regressor.score(x_test,y_test)
print('test_accuracy:',R_test_accuracy)
# Out:
# train_accuracy: 0.9160542446326518
# test_accuracy: 0.8404782538548659

# %%
import matplotlib.pyplot as plt
linear_regression_accuracy = 0.9949918060732188
random_forest_accuracy =0.8404782538548659
accuracy_scores = [linear_regression_accuracy, random_forest_accuracy]
model_names = ['Linear Regression', 'Random Forest Regression']
plt.bar(model_names, accuracy_scores)
plt.xlabel('Regression Models')
plt.ylabel('Test Accuracy')
plt.title('Comparison of Test Accuracy: Linear Regression vs Random Forest Regression')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.neural_network import MLPRegressor
ann_model=MLPRegressor(hidden_layer_sizes=(128,64,32),activation='relu',solver='lbfgs')
ann_model.fit(x_train,y_train)
# Out:
# MLPRegressor(hidden_layer_sizes=(128, 64, 32), solver='lbfgs')

# %%
y_pred=ann_model.predict(x_test)
y_pred
# Out:
# array([82.39999985, 45.38888289, 44.57893383, 50.45618327, 52.30905648,
#        61.88459616, 81.13469153, 46.76661204, 54.21183857, 54.17111697,
#        83.86752033, 69.16031255, 52.10594102, 44.18286859, 45.21267893,
#        70.74813955, 48.97794379, 50.54101606, 90.46471214, 59.64845594,
#        54.66886229, 62.09663788, 43.38912028, 45.51775488, 62.39426403,
#        69.69374905, 77.2153242 , 56.87674817, 58.62779287, 58.76298131,
#        46.83967668, 52.45514527, 78.9122398 , 60.46859849, 50.69646968,
#        65.64567452, 53.72938747, 60.64536038, 55.44778647, 82.62571766,
#        44.491789  , 56.3205418 , 81.44300081, 58.30047429, 56.96162096])

# %%
train_accuracy=ann_model.score(x_train,y_train)
print('train_accuracy(R_Squered):',train_accuracy)
R_test_accuracy=ann_model.score(x_test,y_test)
print('test_accuracy(R_Squered):',test_accuracy)
# Out:
# train_accuracy(R_Squered): 0.9999999999997117
# test_accuracy(R_Squered): 0.9934898217061862

# %%
print('Mean Absolute Error:',metrics.mean_absolute_error(y_test,y_pred))
print('Mean Squared Error:',metrics.mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',math.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Error: 11.333781124252415
# Mean Squared Error: 199.07487889343642
# Root Mean Squared Error: 14.109389742063135

# %%
import matplotlib.pyplot as plt
linear_regression_accuracy =0.9934898217061862
Random_forest_accuracy =0.8404782538548659
ANN= 0.998898217061862
accuracy_scores = [linear_regression_accuracy, Random_forest_accuracy,ANN]
model_names = ['Linear Regression', 'Random Forest Regression','ANN']
plt.bar(model_names, accuracy_scores)
plt.xlabel('Regression Models')
plt.ylabel('Test Accuracy')
plt.title('Comparison of Test Accuracy: Linear Regression vs Random Forest Regression')
plt.show()
